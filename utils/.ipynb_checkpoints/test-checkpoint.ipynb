# %%
from tools import *
from lmfit import minimize, Minimizer, Parameters, Parameter, report_fit
mpt = mpt_data(path = r'C:\Users\cjang.WILDCAT\Desktop\EIS_Manager\data\\', data = ['DE_104_1_30_trimmed.mpt'])
bad_inds = [0,2,3]
mpt.df_raw.head()
# Out:
#             f         re         im      Z_mag    Z_phase     times     E_avg  \
# 0  1000018.60  380.53094  431.64484  575.43121 -48.601131  1.607490 -0.070666
# 1   891246.69  399.59314  454.89511  605.47852 -48.702984  2.204497 -0.070132
# 2   794332.69  428.44955  494.39752  654.21552 -49.087490  2.800481 -0.069679
# 3   707949.81  458.40363  534.23718  703.94830 -49.368668  3.395492 -0.069249
# 4   630956.81  489.62445  583.78113  761.92682 -50.013023  3.990478 -0.068865
#
#       I_avg     Cs/µF     Cp/µF  cycle_number  I Range   |Ewe|/V  \
# 0 -0.000031  0.000369  0.000207           1.0       12  0.000914
# 1 -0.000025  0.000393  0.000222           1.0       12  0.001570
# 2 -0.000019  0.000405  0.000231           1.0       12  0.001983
# 3 -0.000016  0.000421  0.000242           1.0       12  0.001806
# 4 -0.000030  0.000432  0.000254           1.0       12  0.000749
#
#           |I|/A   (Q-Qo)/mA.h  Analog IN 1/V      Y_re      Y_im     Y_mag  \
# 0  1.587914e-06 -2.271957e-08      -0.000058  0.001149  0.001304  0.001738
# 1  2.593358e-06 -2.124911e-08       0.000022  0.001090  0.001241  0.001652
# 2  3.031703e-06 -3.798305e-08      -0.000299  0.001001  0.001155  0.001529
# 3  2.566079e-06 -7.746774e-08      -0.000299  0.000925  0.001078  0.001421
# 4  9.835666e-07 -6.853105e-08       0.000343  0.000843  0.001006  0.001312
#
#      Y_phase       dq/mA.h  Unnamed: 21             w
# 0  48.601131 -2.271957e-08          NaN  6.283302e+06
# 1  48.702984  1.470459e-09          NaN  5.599868e+06
# 2  49.087490 -1.673393e-08          NaN  4.990939e+06
# 3  49.368668 -3.948469e-08          NaN  4.448180e+06
# 4  50.013023  8.936687e-09          NaN  3.964419e+06

# %%
Rs_guess = 18.97257 

R1_guess = 158.27314   
n1_guess = .61219110 
fs1_guess = 15320.8584 

R2_guess = 6413.48882
n2_guess = 0.92134519 
fs2_guess = 20.0517197 

Q3_guess = 10**-7
n3_guess = .5

params = Parameters()
params.add('Rs', value=Rs_guess, min=Rs_guess*.01, max=Rs_guess*100)

params.add('R1', value=R1_guess, min=R1_guess*.1, max=R1_guess*10)
params.add('n1', value=n1_guess, min=.1, max=1)
params.add('fs1', value=fs1_guess, min=10**-2, max=10**10)
#params.add('Q', value=fs_guess, min=10**0.5, max=10**6)

params.add('R2', value=R2_guess, min=R2_guess*.1, max=R2_guess*10)
params.add('n2', value=n2_guess, min=.1, max=1)
params.add('fs2', value=fs2_guess, min=fs2_guess**.1, max=10**10)
#params.add('Q2', value=fs2_guess, min=10**-2, max=10**2)

params.add('Q', value=Q3_guess, min=10**-10, max=10**0)
params.add('n', value=n3_guess, min=.1, max=1)

mpt.mpt_fit(params, circuit = 'R-RQ-RQ-Q')
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 5193
#     # data points      = 168
#     # variables        = 9
#     chi-square         = 37.9215084
#     reduced chi-square = 0.23850005
#     Akaike info crit   = -232.058848
#     Bayesian info crit = -203.943172
# ##  Warning: uncertainties could not be estimated:
#     R1:   at boundary
# [[Variables]]
#     Rs:   165.453398 (init = 18.97257)
#     R1:   15.8273140 (init = 158.2731)
#     n1:   0.99995801 (init = 0.6121911)
#     fs1:  5.3262e+09 (init = 15320.86)
#     R2:   6598.68900 (init = 6413.489)
#     n2:   0.74946785 (init = 0.9213452)
#     fs2:  31146.3272 (init = 20.05172)
#     Q:    4.0546e-07 (init = 1e-07)
#     n:    0.73011883 (init = 0.5)
# None

# %%
mpt.guesser()
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 676
#     # data points      = 168
#     # variables        = 9
#     chi-square         = 1.80613049
#     reduced chi-square = 0.01135931
#     Akaike info crit   = -743.506582
#     Bayesian info crit = -715.390906
# [[Variables]]
#     Rs:   239.505055 +/- 5.45292504 (2.28%) (init = 380.5309)
#     R1:   1398.06363 +/- 440.905669 (31.54%) (init = 4649)
#     n1:   0.91046049 +/- 0.03680508 (4.04%) (init = 0.6121911)
#     fs1:  95238.2286 +/- 10357.5675 (10.88%) (init = 15320.86)
#     R2:   5241.31475 +/- 462.597355 (8.83%) (init = 13949)
#     n2:   0.76680108 +/- 0.01040672 (1.36%) (init = 0.9213452)
#     fs2:  20831.7599 +/- 1927.56647 (9.25%) (init = 20.05172)
#     Q:    3.9549e-07 +/- 1.2329e-09 (0.31%) (init = 1e-07)
#     n:    0.73435283 +/- 5.5043e-04 (0.07%) (init = 0.5)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(R1, R2)   = -0.999
#     C(R1, fs2)  = -0.997
#     C(R2, fs2)  =  0.996
#     C(R1, n1)   = -0.993
#     C(n1, R2)   =  0.993
#     C(Q, n)     = -0.991
#     C(n1, fs1)  =  0.985
#     C(n1, fs2)  =  0.984
#     C(R1, fs1)  = -0.983
#     C(fs1, R2)  =  0.977
#     C(fs1, fs2) =  0.976
#     C(R2, n2)   = -0.945
#     C(R1, n2)   =  0.935
#     C(n1, n2)   = -0.930
#     C(n2, fs2)  = -0.927
#     C(Rs, n2)   =  0.921
#     C(fs1, n2)  = -0.862
#     C(Rs, R2)   = -0.851
#     C(Rs, fs2)  = -0.849
#     C(Rs, R1)   =  0.840
#     C(Rs, n1)   = -0.801
#     C(Rs, fs1)  = -0.745
#     C(n2, n)    = -0.719
#     C(n2, Q)    =  0.662
#     C(Rs, n)    = -0.639
#     C(R2, n)    =  0.601
#     C(n1, n)    =  0.590
#     C(Rs, Q)    =  0.586
#     C(R1, n)    = -0.578
#     C(fs2, n)   =  0.550
#     C(R2, Q)    = -0.548
#     C(n1, Q)    = -0.537
#     C(R1, Q)    =  0.525
#     C(fs1, n)   =  0.505
#     C(fs2, Q)   = -0.498
#     C(fs1, Q)   = -0.456
# None
#                       file      fit_Rs       fit_R1   fit_n1       fit_fs1  \
# 0  DE_104_1_30_trimmed.mpt  239.505055  1398.063635  0.91046  95238.228566
#
#          fit_Q1       fit_R2    fit_n2       fit_fs2        fit_Q2  \
# 0  3.933243e-09  5241.314751  0.766801  20831.759901  2.274630e-08
#
#          fit_Q3    fit_n3
# 0  3.954920e-07  0.734353

# %%
mpt.df[0].head()
# Out:
#             f         re         im      Z_mag    Z_phase     times     E_avg  \
# 0  1000018.60  380.53094  431.64484  575.43121 -48.601131  1.607490 -0.070666
# 1   891246.69  399.59314  454.89511  605.47852 -48.702984  2.204497 -0.070132
# 2   794332.69  428.44955  494.39752  654.21552 -49.087490  2.800481 -0.069679
# 3   707949.81  458.40363  534.23718  703.94830 -49.368668  3.395492 -0.069249
# 4   630956.81  489.62445  583.78113  761.92682 -50.013023  3.990478 -0.068865
#
#       I_avg     Cs/µF     Cp/µF  cycle_number  I Range   |Ewe|/V  \
# 0 -0.000031  0.000369  0.000207           1.0       12  0.000914
# 1 -0.000025  0.000393  0.000222           1.0       12  0.001570
# 2 -0.000019  0.000405  0.000231           1.0       12  0.001983
# 3 -0.000016  0.000421  0.000242           1.0       12  0.001806
# 4 -0.000030  0.000432  0.000254           1.0       12  0.000749
#
#           |I|/A   (Q-Qo)/mA.h  Analog IN 1/V      Y_re      Y_im     Y_mag  \
# 0  1.587914e-06 -2.271957e-08      -0.000058  0.001149  0.001304  0.001738
# 1  2.593358e-06 -2.124911e-08       0.000022  0.001090  0.001241  0.001652
# 2  3.031703e-06 -3.798305e-08      -0.000299  0.001001  0.001155  0.001529
# 3  2.566079e-06 -7.746774e-08      -0.000299  0.000925  0.001078  0.001421
# 4  9.835666e-07 -6.853105e-08       0.000343  0.000843  0.001006  0.001312
#
#      Y_phase       dq/mA.h  Unnamed: 21             w
# 0  48.601131 -2.271957e-08          NaN  6.283302e+06
# 1  48.702984  1.470459e-09          NaN  5.599868e+06
# 2  49.087490 -1.673393e-08          NaN  4.990939e+06
# 3  49.368668 -3.948469e-08          NaN  4.448180e+06
# 4  50.013023  8.936687e-09          NaN  3.964419e+06

# %%
mpt.guesser()
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 211
#     # data points      = 168
#     # variables        = 9
#     chi-square         = 34019178.1
#     reduced chi-square = 213957.095
#     Akaike info crit   = 2070.70313
#     Bayesian info crit = 2098.81881
# ##  Warning: uncertainties could not be estimated:
#     R1:  at initial value
#     R2:  at initial value
# [[Variables]]
#     Rs:  1151.67129 (init = 380.5309)
#     R1:  4649.00000 (init = 4649)
#     n1:  0.83068916 (init = 0.6121911)
#     Q1:  9.6644e+09 (init = 15320.86)
#     R2:  13949.0000 (init = 13949)
#     n2:  0.99761163 (init = 0.9213452)
#     Q2:  6.4383e+09 (init = 20.05172)
#     Q:   2.2379e-06 (init = 1e-07)
#     n:   0.44182005 (init = 0.5)
# None
#                       file       fit_Rs  fit_R1    fit_n1        fit_Q1  \
# 0  DE_104_1_30_trimmed.mpt  1151.671285  4649.0  0.830689  9.664440e+09
#
#     fit_R2    fit_n2        fit_Q2    fit_n     fit_Q
# 0  13949.0  0.997612  6.438274e+09  0.44182  0.000002

# %%
mpt.mpt_plot(fitting = 'on')
# Out:
# No handles with labels found to put in legend.

# %%
2.128415e+06
# Out:
# 2128415.0
